# %% [markdown]
# ### Relu
#   f(x)=max(0,x)

# %%
import numpy as np
x = np.random.uniform(-1,1,1)
relu = np.maximum(0,x)
print(x)
print(relu)
# Out:
# [-0.42470216]
# [0.]

# %% [markdown]
# #### References: [RELU](https://www.kaggle.com/dansbecker/rectified-linear-units-relu-in-deep-learning)
